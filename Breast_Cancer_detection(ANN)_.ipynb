# %% [markdown]
# # Breast Cancer Detection Using Artificial Neural Networks

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-850e1af1-16aa-4f83-b4df-f3b036c5f526" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-850e1af1-16aa-4f83-b4df-f3b036c5f526">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-21dc3c638f66> in <module>()
#       1 from google.colab import files
# ----> 2 uploaded = files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      67   result = _output.eval_js(
#      68       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 69           input_id=input_id, output_id=output_id))
#      70   files = _collections.defaultdict(_six.binary_type)
#      71   # Mapping from original filename to filename as saved locally.
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %% [markdown]
# ## Importing dataset

# %%
import io

dataset = pd.read_csv(io.StringIO(uploaded['breastcancer.csv'].decode('utf-8')))

# %% [markdown]
# ## Printing the dataset

# %%
dataset
# Out:
#            id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0      842302         M  ...          0.4601                  0.11890
# 1      842517         M  ...          0.2750                  0.08902
# 2    84300903         M  ...          0.3613                  0.08758
# 3    84348301         M  ...          0.6638                  0.17300
# 4    84358402         M  ...          0.2364                  0.07678
# ..        ...       ...  ...             ...                      ...
# 564    926424         M  ...          0.2060                  0.07115
# 565    926682         M  ...          0.2572                  0.06637
# 566    926954         M  ...          0.2218                  0.07820
# 567    927241         M  ...          0.4087                  0.12400
# 568     92751         B  ...          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %% [markdown]
# ## Encoding the 'diagnosis' column into 0s and 1s

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
dataset['diagnosis']=encoder.fit_transform(dataset['diagnosis'])
dataset
# Out:
#            id  diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0      842302          1  ...          0.4601                  0.11890
# 1      842517          1  ...          0.2750                  0.08902
# 2    84300903          1  ...          0.3613                  0.08758
# 3    84348301          1  ...          0.6638                  0.17300
# 4    84358402          1  ...          0.2364                  0.07678
# ..        ...        ...  ...             ...                      ...
# 564    926424          1  ...          0.2060                  0.07115
# 565    926682          1  ...          0.2572                  0.06637
# 566    926954          1  ...          0.2218                  0.07820
# 567    927241          1  ...          0.4087                  0.12400
# 568     92751          0  ...          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %% [markdown]
# ## Dropping the unnecessary columns

# %%
dataset=dataset.drop(['radius_worst','perimeter_worst','area_worst','concave points_worst','perimeter_se','id'],axis=1)

# %%
dataset
# Out:
#      diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0            1        17.99  ...          0.4601                  0.11890
# 1            1        20.57  ...          0.2750                  0.08902
# 2            1        19.69  ...          0.3613                  0.08758
# 3            1        11.42  ...          0.6638                  0.17300
# 4            1        20.29  ...          0.2364                  0.07678
# ..         ...          ...  ...             ...                      ...
# 564          1        21.56  ...          0.2060                  0.07115
# 565          1        20.13  ...          0.2572                  0.06637
# 566          1        16.60  ...          0.2218                  0.07820
# 567          1        20.60  ...          0.4087                  0.12400
# 568          0         7.76  ...          0.2871                  0.07039
#
# [569 rows x 26 columns]

# %% [markdown]
# ## Description of dataset

# %%
dataset.describe()
# Out:
#         diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# count  569.000000   569.000000  ...      569.000000               569.000000
# mean     0.372583    14.127292  ...        0.290076                 0.083946
# std      0.483918     3.524049  ...        0.061867                 0.018061
# min      0.000000     6.981000  ...        0.156500                 0.055040
# 25%      0.000000    11.700000  ...        0.250400                 0.071460
# 50%      0.000000    13.370000  ...        0.282200                 0.080040
# 75%      1.000000    15.780000  ...        0.317900                 0.092080
# max      1.000000    28.110000  ...        0.663800                 0.207500
#
# [8 rows x 26 columns]

# %% [markdown]
# ## Information of dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int64
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  area_se                  569 non-null    float64
#  14  smoothness_se            569 non-null    float64
#  15  compactness_se           569 non-null    float64
#  16  concavity_se             569 non-null    float64
#  17  concave points_se        569 non-null    float64
#  18  symmetry_se              569 non-null    float64
#  19  fractal_dimension_se     569 non-null    float64
#  20  texture_worst            569 non-null    float64
#  21  smoothness_worst         569 non-null    float64
#  22  compactness_worst        569 non-null    float64
#  23  concavity_worst          569 non-null    float64
#  24  symmetry_worst           569 non-null    float64
#  25  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(25), int64(1)
# memory usage: 115.7 KB

# %% [markdown]
# ## Checking for any null values

# %%
dataset.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# texture_worst              0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# ## Heatmap showing the correlation values

# %%
plt.figure(figsize=(30,15))
sns.heatmap(dataset.corr(),annot=True)

# %% [markdown]
# ## Pairplots showing the values of different attributes contributing towards the presence/absence of breast cancer

# %%
sns.pairplot(dataset,hue='diagnosis',vars=['radius_mean','texture_mean','perimeter_mean','smoothness_mean','area_mean'])

# %% [markdown]
# ## Getting independent and dependent variables from the dataset

# %%
X=dataset.iloc[:,1:]
X
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0          17.99         10.38  ...          0.4601                  0.11890
# 1          20.57         17.77  ...          0.2750                  0.08902
# 2          19.69         21.25  ...          0.3613                  0.08758
# 3          11.42         20.38  ...          0.6638                  0.17300
# 4          20.29         14.34  ...          0.2364                  0.07678
# ..           ...           ...  ...             ...                      ...
# 564        21.56         22.39  ...          0.2060                  0.07115
# 565        20.13         28.25  ...          0.2572                  0.06637
# 566        16.60         28.08  ...          0.2218                  0.07820
# 567        20.60         29.33  ...          0.4087                  0.12400
# 568         7.76         24.54  ...          0.2871                  0.07039
#
# [569 rows x 25 columns]

# %%
y=dataset.iloc[:,0]
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
X=X.values
y=y.values

# %% [markdown]
# ## Normalization (scaling all the values between 0 and 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X=scaler.fit_transform(X)

# %% [markdown]
# ## Splitting into training and test set

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(X,y,test_size=0.2,random_state=0)

test_x.shape
size=test_x.shape[1]
size
# Out:
# 25

# %% [markdown]
# ## Applying ANN and finding the best values for the hyperparameters

# %%
import keras
from keras.models import Sequential

from keras.layers import Dense 
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV

def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = size))
    classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer ='adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier


classifier = KerasClassifier(build_fn = build_classifier)

parameters={'batch_size': [10,20,30], 'epochs' : [100,200,300]}

#now we will implement gridsearch 

grid_search=GridSearchCV(estimator=classifier,param_grid=parameters,scoring='accuracy',cv=5,n_jobs=-1)

grid_search=grid_search.fit(train_x,train_y)
best_parameters=grid_search.best_params_
# Out:
# Epoch 1/100
# 455/455 [==============================] - 0s 299us/step - loss: 0.6917 - accuracy: 0.6110
# Epoch 2/100
# 455/455 [==============================] - 0s 68us/step - loss: 0.6867 - accuracy: 0.6374
# Epoch 3/100
# 455/455 [==============================] - 0s 68us/step - loss: 0.6740 - accuracy: 0.6440
# Epoch 4/100
# 455/455 [==============================] - 0s 70us/step - loss: 0.6443 - accuracy: 0.7407
# Epoch 5/100
# 455/455 [==============================] - 0s 68us/step - loss: 0.5932 - accuracy: 0.8330
# Epoch 6/100
# 455/455 [==============================] - 0s 67us/step - loss: 0.5185 - accuracy: 0.8637
# Epoch 7/100
# 455/455 [==============================] - 0s 67us/step - loss: 0.4411 - accuracy: 0.9099
# Epoch 8/100
# 455/455 [==============================] - 0s 68us/step - loss: 0
# Epoch 76/100
# 455/455 [==============================] - 0s 62us/step - loss: 0.0601 - accuracy: 0.9824
# Epoch 77/100
# 455/455 [==============================] - 0s 61us/step - loss: 0.0600 - accuracy: 0.9824
# Epoch 78/100
# 455/455 [==============================] - 0s 62us/step - loss: 0.0598 - accuracy: 0.9846
# Epoch 79/100
# 455/455 [==============================] - 0s 63us/step - loss: 0.0590 - accuracy: 0.9868
# Epoch 80/100
# 455/455 [==============================] - 0s 62us/step - loss: 0.0601 - accuracy: 0.9824
# Epoch 81/100
# 455/455 [==============================] - 0s 61us/step - loss: 0.0584 - accuracy: 0.9846
# Epoch 82/100
# 455/455 [==============================] - 0s 57us/step - loss: 0.0577 - accuracy: 0.9868
# Epoch 83/100
# 455/455 [==============================] - 0s 60us/step - loss: 0.0587 - accuracy: 0.9824
# Epoch 84/100
# 455/455 [==============================] - 0s 60us/step - loss: 0.0599 - accuracy: 0.9846
# Epoch 85/100
# 455/455 [==============================] - 0s 64us/step - loss: 0.0628 - accuracy: 0.9802
# Epoch 86/100
# 455/455 [==============================] - 0s 92us/step - loss: 0.0594 - accuracy: 0.9846
# Epoch 87/100
# 455/455 [==============================] - 0s 59us/step - loss: 0.0576 - accuracy: 0.9846
# Epoch 88/100
# 455/455 [==============================] - 0s 65us/step - loss: 0.0596 - accuracy: 0.9846
# Epoch 89/100
# 455/455 [==============================] - 0s 60us/step - loss: 0.0615 - accuracy: 0.9780
# Epoch 90/100
# 455/455 [==============================] - 0s 61us/step - loss: 0.0586 - accuracy: 0.9824
# Epoch 91/100
# 455/455 [==============================] - 0s 59us/step - loss: 0.0592 - accuracy: 0.9824
# Epoch 92/100
# 455/455 [==============================] - 0s 59us/step - loss: 0.0561 - accuracy: 0.9846
# Epoch 93/100
# 455/455 [==============================] - 0s 61us/step - loss: 0.0560 - accuracy: 0.9868
# Epoch 94/100
# 455/455 [==============================] - 0s 60us/step - loss: 0.0563 - accuracy: 0.9846
# Epoch 95/100
# 455/455 [==============================] - 0s 59us/step - loss: 0.0569 - accuracy: 0.9802
# Epoch 96/100
# 455/455 [==============================] - 0s 66us/step - loss: 0.0563 - accuracy: 0.9846
# Epoch 97/100
# 455/455 [==============================] - 0s 69us/step - loss: 0.0561 - accuracy: 0.9846
# Epoch 98/100
# 455/455 [==============================] - 0s 74us/step - loss: 0.0559 - accuracy: 0.9868
# Epoch 99/100
# 455/455 [==============================] - 0s 72us/step - loss: 0.0580 - accuracy: 0.9824
# Epoch 100/100
# 455/455 [==============================] - 0s 69us/step - loss: 0.0560 - accuracy: 0.9846

# %%
best_parameters
# Out:
# {'batch_size': 20, 'epochs': 100}

# %%
batch_size=best_parameters['batch_size']
batch_size
# Out:
# 20

# %%
epochs=best_parameters['epochs']
epochs
# Out:
# 100

# %% [markdown]
# ## Applying ANN with the optimized values of hyperparameters

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier=Sequential()

# %%
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = size))
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Epoch 85/100
# 455/455 [==============================] - 0s 82us/step - loss: 0.0575 - accuracy: 0.9868 - val_loss: 0.1280 - val_accuracy: 0.9737
# Epoch 86/100
# 455/455 [==============================] - 0s 86us/step - loss: 0.0573 - accuracy: 0.9868 - val_loss: 0.1293 - val_accuracy: 0.9649
# Epoch 87/100
# 455/455 [==============================] - 0s 86us/step - loss: 0.0577 - accuracy: 0.9824 - val_loss: 0.1288 - val_accuracy: 0.9737
# Epoch 88/100
# 455/455 [==============================] - 0s 83us/step - loss: 0.0575 - accuracy: 0.9846 - val_loss: 0.1284 - val_accuracy: 0.9737
# Epoch 89/100
# 455/455 [==============================] - 0s 79us/step - loss: 0.0565 - accuracy: 0.9868 - val_loss: 0.1289 - val_accuracy: 0.9737
# Epoch 90/100
# 455/455 [==============================] - 0s 90us/step - loss: 0.0584 - accuracy: 0.9846 - val_loss: 0.1292 - val_accuracy: 0.9737
# Epoch 91/100
# 455/455 [==============================] - 0s 89us/step - loss: 0.0620 - accuracy: 0.9824 - val_loss: 0.1340 - val_accuracy: 0.9737
# Epoch 92/100
# 455/455 [==============================] - 0s 87us/step - loss: 0.0592 - accuracy: 0.9824 - val_loss: 0.1306 - val_accuracy: 0.9737
# Epoch 93/100
# 455/455 [==============================] - 0s 86us/step - loss: 0.0568 - accuracy: 0.9868 - val_loss: 0.1299 - val_accuracy: 0.9737
# Epoch 94/100
# 455/455 [==============================] - 0s 90us/step - loss: 0.0594 - accuracy: 0.9802 - val_loss: 0.1297 - val_accuracy: 0.9737
# Epoch 95/100
# 455/455 [==============================] - 0s 84us/step - loss: 0.0554 - accuracy: 0.9868 - val_loss: 0.1304 - val_accuracy: 0.9649
# Epoch 96/100
# 455/455 [==============================] - 0s 83us/step - loss: 0.0575 - accuracy: 0.9846 - val_loss: 0.1313 - val_accuracy: 0.9649
# Epoch 97/100
# 455/455 [==============================] - 0s 90us/step - loss: 0.0564 - accuracy: 0.9846 - val_loss: 0.1316 - val_accuracy: 0.9737
# Epoch 98/100
# 455/455 [==============================] - 0s 89us/step - loss: 0.0593 - accuracy: 0.9802 - val_loss: 0.1347 - val_accuracy: 0.9649
# Epoch 99/100
# 455/455 [==============================] - 0s 85us/step - loss: 0.0566 - accuracy: 0.9824 - val_loss: 0.1314 - val_accuracy: 0.9737
# Epoch 100/100
# 455/455 [==============================] - 0s 77us/step - loss: 0.0558 - accuracy: 0.9868 - val_loss: 0.1330 - val_accuracy: 0.9737

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'ro', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Predictions on test data

# %%
y_pred = classifier.predict(test_x)
#probability showing the individual having breast cancer (Malignant)
#probability over 50% would indicate the presence of breast cancer

y_pred = (y_pred > 0.5)   #Converting the probabilities into 'true' and 'false'

# %% [markdown]
# ## Confusion matrix and heatmap for visualizing the accuracy of ANN on test data

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_y, y_pred)
cm
# Out:
# array([[66,  1],
#        [ 2, 45]])

# %%
sns.heatmap(cm,annot=True)

# %% [markdown]
# ## Accuracy on test data

# %%
print("Accuracy Score:",round((cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1])*100,2))
# Out:
# Accuracy Score: 97.37

# %% [markdown]
# # End of Project.
